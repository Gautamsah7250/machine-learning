# %%
student = {
    "name": "Ram",
    "age": 20,
    "faculty": "BCE"
}

# %%
import sys
print(sys.executable)
# Out:
# /Users/gautamsah/Desktop/Machine learning/.venv/bin/python

# %%
# !{sys.executable} -m pip install pandas
# Out:
# zsh:1: parse error near `-m'

# %%
import pandas as pd

# %%
df = pd.DataFrame([student])

# %%
df.head()
# Out:
#   name  age faculty
# 0  Ram   20     BCE

# %%
df.tail()
# Out:
#   name  age faculty
# 0  Ram   20     BCE

# %%
df.shape
# Out:
# (1, 3)

# %%
df.columns
# Out:
# Index(['name', 'age', 'faculty'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     1 non-null      str
#  1   age      1 non-null      int64
#  2   faculty  1 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 156.0 bytes

# %%
df.describe()
# Out:
#         age
# count   1.0
# mean   20.0
# std     NaN
# min    20.0
# 25%    20.0
# 50%    20.0
# 75%    20.0
# max    20.0

# %%
df["name"]
# Out:
# 0    Ram
# Name: name, dtype: str

# %%
df[['name', 'age']]
# Out:
#   name  age
# 0  Ram   20
