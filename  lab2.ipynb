# %%
student = {
    "name": "Ram",
    "age": 20,
    "faculty": "BCE"
}

# %%
student["age"]
# Out:
# 20

# %%
student["name"]
# Out:
# 'Ram'

# %%
student["faculty"]
# Out:
# 'BCE'

# %%
student = {"a":1, "b":2}

# %%
print(student)
# Out:
# {'a': 1, 'b': 2}

# %%
student["age"] = 21

# %%
print(student)
# Out:
# {'a': 1, 'b': 2, 'age': 21}

# %%
student.get("age")
# Out:
# 21

# %%
student["faculty"] = "BCE"

# %%
print(student)
# Out:
# {'a': 1, 'b': 2, 'age': 21, 'faculty': 'BCE'}

# %%
student["faculty"] = "civil"

# %%
print(student)
# Out:
# {'a': 1, 'b': 2, 'age': 21, 'faculty': 'civil'}

# %%
del student["b"]

# %%
print(student)
# Out:
# {'a': 1, 'age': 21, 'faculty': 'civil'}

# %%
student.pop("a")
# Out:
# 1

# %%
student.popitem()
# Out:
# ('faculty', 'civil')

# %%
student.clear()

# %%
print(student)
# Out:
# {}

# %%
print(student)
# Out:
# {'name': 'Ram', 'age': 20, 'faculty': 'BCE'}

# %%
new_student = student.copy()

# %%
print (new_student)
# Out:
# {'name': 'Ram', 'age': 20, 'faculty': 'BCE'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'faculty'])

# %%
student.values()
# Out:
# dict_values(['Ram', 20, 'BCE'])

# %%
student.items()
# Out:
# dict_items([('name', 'Ram'), ('age', 20), ('faculty', 'BCE')])

# %%
    "a" in student
# Out:
# False

# %%
"faculty" in student
# Out:
# True

# %%
len(student)
# Out:
# 3

# %%
for k in student:
    print(k)
# Out:
# name
# age
# faculty

# %%
for v in student.values():
    print(v)
# Out:
# Ram
# 20
# BCE

# %%
print (new_student)
# Out:
# {'name': 'Ram', 'age': 20, 'faculty': 'BCE'}

# %%
for k,v in student.items():

    print(k,v)
# Out:
# name Ram
# age 20
# faculty BCE
